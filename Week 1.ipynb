# %% [markdown]
# <a href="https://colab.research.google.com/github/gustijuno/PCVK_Genap_2022/blob/main/Week%201.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **PRAKTIKUM**

# %%
import numpy as np
import pandas as pd
import cv2 as cv
from google.colab.patches import cv2_imshow #for image display
from skimage import io
from skimage import transform
from PIL import Image
import matplotlib.pylab as plt

# %%
urls = ["https://iiif.lib.ncsu.edu/iiif/0052574/full/800,/0/default.jpg",
        "https://iiif.lib.ncsu.edu/iiif/0016007/full/800,/0/default.jpg",
        "https://placekitten.com/800/571","https://asset-a.grid.id/crop/0x0:0x0/x/photo/2019/05/15/3488915245.jpg"]

for url in urls:
          image = io.imread(url)
          image = cv.resize(image, (0,0), fx=0.5, fy=0.5)
          image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
          final_frame = cv.hconcat((image, image_2))
          cv2_imshow(final_frame)
          print('/n')
# Out:
# <PIL.Image.Image image mode=RGB size=800x276 at 0x7FF182D7E990>
# /n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FF182D7EE50>
# /n
# <PIL.Image.Image image mode=RGB size=800x286 at 0x7FF182D7E790>
# /n
# <PIL.Image.Image image mode=RGB size=960x270 at 0x7FF182D7E510>
# /n

# %%
tinggi = image_2.shape[0]
lebar = image_2.shape[1]
kedalaman = image_2.shape[2]
print("resolusi image: tinggi x lebar = ", tinggi," x ",lebar, "kedalaman :", kedalaman)
cv2_imshow(image_2)
# Out:
# resolusi image: tinggi x lebar =  270  x  480 kedalaman : 3
# <PIL.Image.Image image mode=RGB size=480x270 at 0x7FF185D4E510>

# %%
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for y in range (lebar):
  image_3[int((tinggi)/2),y] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=960x270 at 0x7FF182E1FC90>

# %% [markdown]
# **TUGAS**

# %%
#VERTICAL
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

for x in range (tinggi):
  image_3[x,int((lebar)/2)] = [255,255,255]

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=960x270 at 0x7FF181275890>

# %%
#CROSS
image_2 = cv.cvtColor(image, cv.COLOR_BGR2RGB)
image_3 = cv.cvtColor(image, cv.COLOR_BGR2RGB)

cv.line(image_3,(0,0),(lebar,tinggi),(255,255,255),1)
cv.line(image_3,(0,tinggi),(lebar,0),(255,255,255),1)

final_frame = cv.hconcat((image_2, image_3))
cv2_imshow(final_frame)
# Out:
# <PIL.Image.Image image mode=RGB size=960x270 at 0x7FF182D9D590>
