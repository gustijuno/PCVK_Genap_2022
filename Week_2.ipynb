# %% [markdown]
# <a href="https://colab.research.google.com/github/gustijuno/PCVK_Genap_2022/blob/main/Week_2.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive

drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import cv2 as cv
from google.colab.patches import cv2_imshow
from skimage import io
import matplotlib.pyplot as plt
import numpy as np
img = cv.imread('/content/drive/MyDrive/Iron_Man_bleeding_edge.jpg')
plt.imshow(img)

# %%
img2 = img
img3 = cv.cvtColor(img,cv.COLOR_BGR2RGB)
plt.imshow(img3)

# %%
img_gray = cv.imread('/content/drive/MyDrive/Iron_Man_bleeding_edge.jpg', cv.IMREAD_GRAYSCALE)
plt.imshow(img_gray)

# %%
plt.imshow(img_gray, cmap='gray')

# %%
plt.imshow(img_gray, cmap='magma')

# %%
img4 = cv.resize(cv.cvtColor(img,cv.COLOR_BGR2RGB),(512,1024))
plt.imshow(img4)

# %%
img5 = cv.flip(cv.cvtColor(img,cv.COLOR_BGR2RGB),0)

fig = plt.figure(figsize = (10,10))
ax = fig.add_subplot(111)
ax.imshow(img5)

# %%
black_img = np.zeros(shape=(512,512,3),dtype=np.int16)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(384,0),pt2=(510,150),color=(0,255,0),thickness=10)
plt.imshow(black_img)

# %%
cv.rectangle(black_img,pt1=(200,200),pt2=(300,300),color=(0,0,255),thickness=15)
plt.imshow(black_img)

# %%
cv.circle(black_img,center=(100,100),radius=50,color=(255,0,0),thickness=8)
plt.imshow(black_img)

# %%
cv.line(black_img,pt1=(0,0),pt2=(512,512),color=(255,255,255),thickness=5)
plt.imshow(black_img)

# %%
font = cv.FONT_HERSHEY_SIMPLEX
cv.putText(black_img,text='Hello',org=(10,500),fontFace=font,fontScale=4,color=(255,255,0),thickness=2, lineType=cv.LINE_AA)
plt.imshow(black_img)

# %%
black_img2=np.zeros(shape=(512,512,3),dtype=np.int32)
plt.imshow(black_img2)

# %%
vertices = np.array([[100,300],[200,200],[400,300],[200,400]],dtype=np.int32)
vertices
# Out:
# array([[100, 300],
#        [200, 200],
#        [400, 300],
#        [200, 400]], dtype=int32)

# %%
pts=vertices.reshape((-1,1,2))
pts
# Out:
# array([[[100, 300]],
#
#        [[200, 200]],
#
#        [[400, 300]],
#
#        [[200, 400]]], dtype=int32)

# %%
cv.polylines(black_img2,[pts],isClosed=True,color=(255,0,0),thickness=5)
plt.imshow(black_img2)

# %% [markdown]
# **TUGAS**

# %% [markdown]
# Red,Green,Blue

# %%
imgRGB = cv.resize(cv.imread('/content/drive/MyDrive/Iron_Man_bleeding_edge.jpg'), (200,125))
r,g,b = cv.split(imgRGB)
zeros=np.zeros(imgRGB.shape[:2],dtype='uint8')
red = cv2_imshow(cv.merge([r,zeros,zeros]))
green = cv2_imshow(cv.merge([zeros,g,zeros]))
blue = cv2_imshow(cv.merge([zeros,zeros,b]))
imgRG = cv2_imshow(cv.merge([r,g,zeros])) #Red-Green
imgGB = cv2_imshow(cv.merge([g,b,zeros])) #Green-Blue
# Out:
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F4A53A18150>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F4A53A18450>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F4A53AB2890>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F4A53A22890>
# <PIL.Image.Image image mode=RGB size=200x125 at 0x7F4A53A628D0>

# %% [markdown]
# Baris 10-100, kolom 10-100

# %%
cropImg = cv.cvtColor(img,cv.COLOR_BGR2RGB)
cropImg = cropImg[10:100,10:100]

plt.imshow(cropImg)

# %% [markdown]
# baris ke 5-30 Green

# %%
imgG = cv.resize(cv.imread('/content/drive/MyDrive/Iron_Man_bleeding_edge.jpg'), (200,125))
r,g,b = cv.split(imgG)
croppedImg = g[5:30,0:500]

plt.imshow(croppedImg)

# %% [markdown]
# bentuk acak

# %%
img7 = cv.imread('/content/drive/MyDrive/female.jpg', )
photos = cv.cvtColor(img7,cv.COLOR_BGR2RGB)
cv.rectangle(photos,pt1=(384,0),pt2=(510,150),color=(0,500,0),thickness=10)
cv.rectangle(photos,pt1=(50,200),pt2=(200,150),color=(0,0,255),thickness=5)
cv.rectangle(photos,pt1=(700,500),pt2=(300,400),color=(300,100,0),thickness=-1)
cv.rectangle(photos,pt1=(300,450),pt2=(150,230),color=(255,0,255),thickness=7)
cv.rectangle(photos,pt1=(100,10),pt2=(650,90),color=(0,100,255),thickness=-1)
plt.imshow(photos)

# %%
photos = cv.flip(cv.cvtColor(img7, cv.COLOR_BGR2RGB), 0)
plt.imshow(photos)

# %%
photo = cv.imread('/content/drive/MyDrive/Screenshot (66).png')
photos = cv.cvtColor(photo,cv.COLOR_BGR2RGB)
cv.circle(photos,center=(1275,150),radius=60,color=(255,0,0),thickness=10)
cv.rectangle(photos,pt1=(1190,70),pt2=(1350,300),color=(0,0,255),thickness=7)
plt.imshow(photos)

# %%
pict = cv.imread('/content/drive/MyDrive/female.jpg')
picts = cv.cvtColor(pict,cv.COLOR_BGR2RGB)
cv.rectangle(picts,pt1=(50,450),pt2=(100,500),color=(300,200,0),thickness=7)
plt.imshow(picts)

# %%
picts2 = picts
fonts = cv.FONT_HERSHEY_SCRIPT_COMPLEX
cv.putText(picts2,text='Female',org=(225,550),fontFace=font,fontScale=4,color=(300,200,0),thickness=5,lineType=cv.LINE_AA)
plt.imshow(picts2)
